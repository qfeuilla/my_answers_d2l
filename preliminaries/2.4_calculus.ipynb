# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ** Question 1 : Plot the function  $ y=f(x)=x^3−1x $  and its tangent line when $ x=1 $. **
#
# -----
#
# the point slop formula is :
#
# $ y - y_1 = m (x - x_1) $
#
# -----
#
# $ f(x) = x^3 - (1 / x) $
#
# $ f'(x) = 3x^2 + x^{-2} $
#
# $ m = f'(1) = 4 $
#
# $ y_1 = f(1) = 0 $
#
# $ y = 4 ( x - 1 ) $
#
# $ y = 4 * x - 4 $

# %%
def f(x):
    return x ** 3 - (1 / x)

# %%
x = np.arange(0, 4, 0.05)
plt.plot(x, f(x))
plt.plot(x, 4 * x - 4)
plt.show()
# Out:
# <ipython-input-3-a270bb1b12ee>:2: RuntimeWarning: divide by zero encountered in true_divide
#   return x ** 3 - (1 / x)

# %% [markdown]
# ** Question 2 : Find the gradient of the function $ f(x)=3*x_1^2+5e^{x_2} $.**
#
# $ \nabla_x f(x) = [\frac{\partial f(x)}{\partial x_1}, \frac{\partial f(x)}{\partial x_2}]^\top$
#
# $ \nabla_x f(x) = [6x_1, 5e^{x_2}]^\top$

# %% [markdown]
# ** Question 3 : What is the gradient of the function $ f(x)=\left \| x \right \|_2 $?**
#
# $ \left \| x \right \|_2 = \sqrt{x^\top x} $
#
# let $ u = x^\top x$
#
# then using the chain rule :
#
# $ \nabla x f(x) = \frac{\partial u^\frac{1}{2}}{\partial u} * \frac{\partial u}{\partial x}  $
#
# $ \nabla x f(x) = (\frac{1}{2} * u^{-\frac{1}{2}} ) * 2x $
#
# $ \nabla x f(x) = \frac{2x}{2 * \sqrt{x^\top x} } $
#
# $ \nabla x f(x) = \frac{x}{\left \| x \right \|_2} $

# %% [markdown]
# ** Question 4 : Can you write out the chain rule for the case where $ u=f(x,y,z) $ and $ x=x(a,b) $, $ y=y(a,b) $, and $ z=z(a,b) $ ?**
#
# $ \frac{\partial u}{\partial a} = \frac{\partial u}{\partial x} * \frac{\partial x}{\partial a} + \frac{\partial u}{\partial y} * \frac{\partial y}{\partial a} + \frac{\partial u}{\partial z} * \frac{\partial z}{\partial a}$
#
# $ \frac{\partial u}{\partial b} = \frac{\partial u}{\partial x} * \frac{\partial x}{\partial b} + \frac{\partial u}{\partial y} * \frac{\partial y}{\partial b} + \frac{\partial u}{\partial z} * \frac{\partial z}{\partial b}$
