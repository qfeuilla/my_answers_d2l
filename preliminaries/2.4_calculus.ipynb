# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x):
    return x ** 3 - (1 / x)

# %%
x = np.arange(0, 3, 0.1)
plt.plot(f(x))
plt.plot(4*x - 4)
plt.show()
# Out:
# <ipython-input-4-a270bb1b12ee>:2: RuntimeWarning: divide by zero encountered in true_divide
#   return x ** 3 - (1 / x)
